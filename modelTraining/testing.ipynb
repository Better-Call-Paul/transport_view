# %%
import pandas as pd
from joblib import load

# Load the model from the file
model = load('../models/fiveMillionDatapointModel.joblib')

# %%
import numpy as np
from sodapy import Socrata
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
# Initialize the Socrata client and fetch data
client = Socrata("data.ny.gov", "UySBT3QA7VB8OpdyYVybWrBiN")
results = client.get("wujg-7c2s", limit=500000)
results
# Out:
# [{'transit_timestamp': '2024-09-17T05:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '392',
#   'station_complex': '125 St (4,5,6)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Fair Fare',
#   'ridership': '13.0',
#   'transfers': '0.0',
#   'latitude': '40.80414',
#   'longitude': '-73.93759',
#   'georeference': {'type': 'Point', 'coordinates': [-73.93759, 40.80414]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '794'},
#  {'transit_timestamp': '2024-05-27T06:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '419',
#   'station_complex': '225 St (2,5)',
#   'borough': 'Bronx',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Other',
#   'ridership': '1.0',
#   'transfers': '0.0',
#   'latitude': '40.888023',
#   'longitude': '-73.860344',
#   'georeference': {'type': 'Point', 'coordinates': [-73.860344, 40.888023]},
#   ':@computed_region_kjdx_g34t': '2032',
#   ':@computed_region_yamh_8v7k': '307',
#   ':@computed_region_wbg7_3whc': '679'},
#  {'transit_timestamp': '2024-05-27T06:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '427',
#   'station_complex': 'West Farms Sq-E Tremont Av (2,5)',
#   'borough': 'Bronx',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Other',
#   'ridership': '6.0',
#   'transfers': '1.0',
#   'latitude': '40.840294',
#   'longitude': '-73.88005',
#   'georeference': {'type': 'Point', 'coordinates': [-73.88005, 40.840294]},
#   ':@computed_region_kjdx_g34t': '2032',
#   ':@computed_region_yamh_8v7k': '307',
#   ':@computed_region_wbg7_3whc': '673'},
#  {'transit_timestamp': '2024-05-27T06:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '47',
#   'station_complex': 'Newkirk Plaza (B,Q)',
#   'borough': 'Brooklyn',
#   'payment_method': 'omny',
#   'fare_class_category': 'OMNY - Full Fare',
#   'ridership': '65.0',
#   'transfers': '3.0',
#   'latitude': '40.635082',
#   'longitude': '-73.96279',
#   'georeference': {'type': 'Point', 'coordinates': [-73.96279, 40.635082]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '810'},
#  {'transit_timestamp': '2024-05-27T06:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '471',
#   'station_complex': '34 St-Hudson Yards (7)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Fair Fare',
#   'ridership': '3.0',
#   'transfers': '0.0',
#   'latitude': '40.755882',
#   'longitude': '-74.00191',
#   'georeference': {'type': 'Point', 'coordinates': [-74.00191, 40.755882]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '717'},
#  {'transit_timestamp': '2024-05-27T06:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '56',
#   'station_complex': 'Ocean Pkwy (Q)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Other',
#   'ridership': '1.0',
#   'transfers': '0.0',
#   'latitude': '40.576313',
#   'longitude': '-73.9685',
#   'georeference': {'type': 'Point', 'coordinates': [-73.9685, 40.576313]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '818'},
#  {'transit_timestamp': '2024-05-27T06:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '620',
#   'station_complex': 'Court St (R)/Borough Hall (2,3,4,5)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 30-Day',
#   'ridership': '6.0',
#   'transfers': '0.0',
#   'latitude': '40.6941',
#   'longitude': '-73.99015',
#   'georeference': {'type': 'Point', 'coordinates': [-73.99015, 40.6941]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '880'},
#  {'transit_timestamp': '2024-05-27T06:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '9',
#   'station_complex': '57 St-7 Av (N,Q,R,W)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '17.0',
#   'transfers': '0.0',
#   'latitude': '40.764664',
#   'longitude': '-73.98066',
#   'georeference': {'type': 'Point', 'coordinates': [-73.98066, 40.764664]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '742'},
#  {'transit_timestamp': '2024-05-27T07:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '151',
#   'station_complex': '145 St (A,C,B,D)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Other',
#   'ridership': '30.0',
#   'transfers': '1.0',
#   'latitude': '40.824783',
#   'longitude': '-73.944214',
#   'georeference': {'type': 'Point', 'coordinates': [-73.944214, 40.824783]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '758'},
#  {'transit_timestamp': '2024-05-27T07:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '169',
#   'station_complex': 'Canal St (A,C,E)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Other',
#   'ridership': '3.0',
#   'transfers': '0.0',
#   'latitude': '40.720825',
#   'longitude': '-74.005226',
#   'georeference': {'type': 'Point', 'coordinates': [-74.005226, 40.720825]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '737'},
#  {'transit_timestamp': '2024-05-27T07:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '204',
#   'station_complex': 'Beach 67 St (A)',
#   'borough': 'Queens',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 30-Day',
#   'ridership': '4.0',
#   'transfers': '0.0',
#   'latitude': '40.590927',
#   'longitude': '-73.79692',
#   'georeference': {'type': 'Point', 'coordinates': [-73.79692, 40.590927]},
#   ':@computed_region_kjdx_g34t': '2137',
#   ':@computed_region_yamh_8v7k': '196',
#   ':@computed_region_wbg7_3whc': '1028'},
#  {'transit_timestamp': '2024-05-27T07:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '232',
#   'station_complex': '2 Av (F)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '15.0',
#   'transfers': '0.0',
#   'latitude': '40.7234',
#   'longitude': '-73.98994',
#   'georeference': {'type': 'Point', 'coordinates': [-73.98994, 40.7234]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '719'},
#  {'transit_timestamp': '2024-05-27T07:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '248',
#   'station_complex': 'Avenue N (F)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Seniors & Disability',
#   'ridership': '4.0',
#   'transfers': '1.0',
#   'latitude': '40.61514',
#   'longitude': '-73.9742',
#   'georeference': {'type': 'Point', 'coordinates': [-73.9742, 40.61514]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '813'},
#  {'transit_timestamp': '2024-05-27T07:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '283',
#   'station_complex': 'Greenpoint Av (G)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 30-Day',
#   'ridership': '11.0',
#   'transfers': '0.0',
#   'latitude': '40.731354',
#   'longitude': '-73.95445',
#   'georeference': {'type': 'Point', 'coordinates': [-73.95445, 40.731354]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '901'},
#  {'transit_timestamp': '2024-05-27T07:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '423',
#   'station_complex': 'Allerton Av (2,5)',
#   'borough': 'Bronx',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '19.0',
#   'transfers': '0.0',
#   'latitude': '40.865463',
#   'longitude': '-73.867355',
#   'georeference': {'type': 'Point', 'coordinates': [-73.867355, 40.865463]},
#   ':@computed_region_kjdx_g34t': '2032',
#   ':@computed_region_yamh_8v7k': '307',
#   ':@computed_region_wbg7_3whc': '704'},
#  {'transit_timestamp': '2024-05-27T07:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '444',
#   'station_complex': 'Gun Hill Rd (5)',
#   'borough': 'Bronx',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Fair Fare',
#   'ridership': '6.0',
#   'transfers': '0.0',
#   'latitude': '40.869526',
#   'longitude': '-73.84638',
#   'georeference': {'type': 'Point', 'coordinates': [-73.84638, 40.869526]},
#   ':@computed_region_kjdx_g34t': '2032',
#   ':@computed_region_yamh_8v7k': '307',
#   ':@computed_region_wbg7_3whc': '706'},
#  {'transit_timestamp': '2024-05-27T07:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '464',
#   'station_complex': 'Vernon Blvd-Jackson Av (7)',
#   'borough': 'Queens',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 30-Day',
#   'ridership': '13.0',
#   'transfers': '0.0',
#   'latitude': '40.742626',
#   'longitude': '-73.95358',
#   'georeference': {'type': 'Point', 'coordinates': [-73.95358, 40.742626]},
#   ':@computed_region_kjdx_g34t': '2137',
#   ':@computed_region_yamh_8v7k': '196',
#   ':@computed_region_wbg7_3whc': '873'},
#  {'transit_timestamp': '2024-05-27T07:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '617',
#   'station_complex': 'Atlantic Av-Barclays Ctr (B,D,N,Q,R,2,3,4,5)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Other',
#   'ridership': '36.0',
#   'transfers': '0.0',
#   'latitude': '40.68446',
#   'longitude': '-73.97689',
#   'georeference': {'type': 'Point', 'coordinates': [-73.97689, 40.68446]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '895'},
#  {'transit_timestamp': '2024-05-27T07:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '628',
#   'station_complex': 'Fulton St (A,C,J,Z,2,3,4,5)',
#   'borough': 'Manhattan',
#   'payment_method': 'omny',
#   'fare_class_category': 'OMNY - Full Fare',
#   'ridership': '227.0',
#   'transfers': '3.0',
#   'latitude': '40.710373',
#   'longitude': '-74.00657',
#   'georeference': {'type': 'Point', 'coordinates': [-74.00657, 40.710373]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '797'},
#  {'transit_timestamp': '2024-05-27T07:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '85',
#   'station_complex': '75 St-Elderts Ln (J,Z)',
#   'borough': 'Queens',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 30-Day',
#   'ridership': '3.0',
#   'transfers': '0.0',
#   'latitude': '40.691322',
#   'longitude': '-73.86714',
#   'georeference': {'type': 'Point', 'coordinates': [-73.86714, 40.691322]},
#   ':@computed_region_kjdx_g34t': '2137',
#   ':@computed_region_yamh_8v7k': '196',
#   ':@computed_region_wbg7_3whc': '1168'},
#  {'transit_timestamp': '2024-05-27T08:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '126',
#   'station_complex': 'Jefferson St (L)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Fair Fare',
#   'ridership': '2.0',
#   'transfers': '0.0',
#   'latitude': '40.706608',
#   'longitude': '-73.92291',
#   'georeference': {'type': 'Point', 'coordinates': [-73.92291, 40.706608]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '820'},
#  {'transit_timestamp': '2024-05-27T08:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '310',
#   'station_complex': '96 St (1,2,3)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Fair Fare',
#   'ridership': '20.0',
#   'transfers': '1.0',
#   'latitude': '40.79392',
#   'longitude': '-73.97232',
#   'georeference': {'type': 'Point', 'coordinates': [-73.97232, 40.79392]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '752'},
#  {'transit_timestamp': '2024-05-27T08:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '341',
#   'station_complex': 'Eastern Pkwy-Brooklyn Museum (2,3)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Other',
#   'ridership': '6.0',
#   'transfers': '0.0',
#   'latitude': '40.671986',
#   'longitude': '-73.96438',
#   'georeference': {'type': 'Point', 'coordinates': [-73.96438, 40.671986]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '821'},
#  {'transit_timestamp': '2024-05-27T08:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '369',
#   'station_complex': 'Elder Av (6)',
#   'borough': 'Bronx',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '34.0',
#   'transfers': '0.0',
#   'latitude': '40.828583',
#   'longitude': '-73.87916',
#   'georeference': {'type': 'Point', 'coordinates': [-73.87916, 40.828583]},
#   ':@computed_region_kjdx_g34t': '2032',
#   ':@computed_region_yamh_8v7k': '307',
#   ':@computed_region_wbg7_3whc': '709'},
#  {'transit_timestamp': '2024-05-27T08:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '405',
#   'station_complex': '23 St (6)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Other',
#   'ridership': '1.0',
#   'transfers': '0.0',
#   'latitude': '40.739864',
#   'longitude': '-73.9866',
#   'georeference': {'type': 'Point', 'coordinates': [-73.9866, 40.739864]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '734'},
#  {'transit_timestamp': '2024-05-27T08:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '413',
#   'station_complex': 'Wall St (4,5)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Seniors & Disability',
#   'ridership': '2.0',
#   'transfers': '0.0',
#   'latitude': '40.707558',
#   'longitude': '-74.01186',
#   'georeference': {'type': 'Point', 'coordinates': [-74.01186, 40.707558]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '721'},
#  {'transit_timestamp': '2024-05-27T08:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '436',
#   'station_complex': 'Harlem-148 St (3)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Fair Fare',
#   'ridership': '7.0',
#   'transfers': '0.0',
#   'latitude': '40.82388',
#   'longitude': '-73.93647',
#   'georeference': {'type': 'Point', 'coordinates': [-73.93647, 40.82388]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '798'},
#  {'transit_timestamp': '2024-05-27T08:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '451',
#   'station_complex': 'Junction Blvd (7)',
#   'borough': 'Queens',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Students',
#   'ridership': '31.0',
#   'transfers': '1.0',
#   'latitude': '40.749146',
#   'longitude': '-73.86953',
#   'georeference': {'type': 'Point', 'coordinates': [-73.86953, 40.749146]},
#   ':@computed_region_kjdx_g34t': '2137',
#   ':@computed_region_yamh_8v7k': '196',
#   ':@computed_region_wbg7_3whc': '843'},
#  {'transit_timestamp': '2024-05-27T08:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '46',
#   'station_complex': 'Cortelyou Rd (Q)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Full Fare',
#   'ridership': '23.0',
#   'transfers': '0.0',
#   'latitude': '40.640926',
#   'longitude': '-73.96389',
#   'georeference': {'type': 'Point', 'coordinates': [-73.96389, 40.640926]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '810'},
#  {'transit_timestamp': '2024-05-27T08:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '53',
#   'station_complex': 'Neck Rd (Q)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 30-Day',
#   'ridership': '24.0',
#   'transfers': '0.0',
#   'latitude': '40.595245',
#   'longitude': '-73.95516',
#   'georeference': {'type': 'Point', 'coordinates': [-73.95516, 40.595245]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '812'},
#  {'transit_timestamp': '2024-05-27T08:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '606',
#   'station_complex': 'Court Sq (E,G,M,7)',
#   'borough': 'Queens',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Students',
#   'ridership': '3.0',
#   'transfers': '0.0',
#   'latitude': '40.747025',
#   'longitude': '-73.94383',
#   'georeference': {'type': 'Point', 'coordinates': [-73.94383, 40.747025]},
#   ':@computed_region_kjdx_g34t': '2137',
#   ':@computed_region_yamh_8v7k': '196',
#   ':@computed_region_wbg7_3whc': '873'},
#  {'transit_timestamp': '2024-05-27T08:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '624',
#   'station_complex': 'Chambers St (A,C)/WTC (E)/Park Pl (2,3)/Cortlandt (R,W)',
#   'borough': 'Manhattan',
#   'payment_method': 'omny',
#   'fare_class_category': 'OMNY - Seniors & Disability',
#   'ridership': '1.0',
#   'transfers': '0.0',
#   'latitude': '40.71411',
#   'longitude': '-74.00858',
#   'georeference': {'type': 'Point', 'coordinates': [-74.00858, 40.71411]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '723'},
#  {'transit_timestamp': '2024-05-27T09:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '14',
#   'station_complex': '23 St (R,W)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Students',
#   'ridership': '1.0',
#   'transfers': '0.0',
#   'latitude': '40.741302',
#   'longitude': '-73.98934',
#   'georeference': {'type': 'Point', 'coordinates': [-73.98934, 40.741302]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '734'},
#  {'transit_timestamp': '2024-05-27T09:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '147',
#   'station_complex': '175 St (A)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Full Fare',
#   'ridership': '33.0',
#   'transfers': '0.0',
#   'latitude': '40.84739',
#   'longitude': '-73.939705',
#   'georeference': {'type': 'Point', 'coordinates': [-73.939705, 40.84739]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '792'},
#  {'transit_timestamp': '2024-05-27T09:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '159',
#   'station_complex': '81 St-Museum of Natural History (C,B)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '6.0',
#   'transfers': '0.0',
#   'latitude': '40.781433',
#   'longitude': '-73.972145',
#   'georeference': {'type': 'Point', 'coordinates': [-73.972145, 40.781433]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749'},
#  {'transit_timestamp': '2024-05-27T09:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '169',
#   'station_complex': 'Canal St (A,C,E)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Full Fare',
#   'ridership': '15.0',
#   'transfers': '0.0',
#   'latitude': '40.720825',
#   'longitude': '-74.005226',
#   'georeference': {'type': 'Point', 'coordinates': [-74.005226, 40.720825]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '737'},
#  {'transit_timestamp': '2024-05-27T09:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '181',
#   'station_complex': 'Utica Av (A,C)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Other',
#   'ridership': '13.0',
#   'transfers': '0.0',
#   'latitude': '40.679363',
#   'longitude': '-73.93073',
#   'georeference': {'type': 'Point', 'coordinates': [-73.93073, 40.679363]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '891'},
#  {'transit_timestamp': '2024-05-27T09:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '194',
#   'station_complex': '111 St (A)',
#   'borough': 'Queens',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '7.0',
#   'transfers': '0.0',
#   'latitude': '40.68433',
#   'longitude': '-73.83216',
#   'georeference': {'type': 'Point', 'coordinates': [-73.83216, 40.68433]},
#   ':@computed_region_kjdx_g34t': '2137',
#   ':@computed_region_yamh_8v7k': '196',
#   ':@computed_region_wbg7_3whc': '1166'},
#  {'transit_timestamp': '2024-05-27T09:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '261',
#   'station_complex': 'Forest Hills-71 Av (E,F,M,R)',
#   'borough': 'Queens',
#   'payment_method': 'omny',
#   'fare_class_category': 'OMNY - Full Fare',
#   'ridership': '155.0',
#   'transfers': '32.0',
#   'latitude': '40.72169',
#   'longitude': '-73.84452',
#   'georeference': {'type': 'Point', 'coordinates': [-73.84452, 40.72169]},
#   ':@computed_region_kjdx_g34t': '2137',
#   ':@computed_region_yamh_8v7k': '196',
#   ':@computed_region_wbg7_3whc': '845'},
#  {'transit_timestamp': '2024-05-27T09:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '313',
#   'station_complex': '72 St (1,2,3)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '56.0',
#   'transfers': '0.0',
#   'latitude': '40.778454',
#   'longitude': '-73.98197',
#   'georeference': {'type': 'Point', 'coordinates': [-73.98197, 40.778454]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '750'},
#  {'transit_timestamp': '2024-05-27T09:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '327',
#   'station_complex': 'Chambers St (1,2,3)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Full Fare',
#   'ridership': '10.0',
#   'transfers': '0.0',
#   'latitude': '40.715477',
#   'longitude': '-74.00927',
#   'georeference': {'type': 'Point', 'coordinates': [-74.00927, 40.715477]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '723'},
#  {'transit_timestamp': '2024-05-27T09:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '336',
#   'station_complex': 'Hoyt St (2,3)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Other',
#   'ridership': '6.0',
#   'transfers': '0.0',
#   'latitude': '40.690544',
#   'longitude': '-73.98506',
#   'georeference': {'type': 'Point', 'coordinates': [-73.98506, 40.690544]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '880'},
#  {'transit_timestamp': '2024-05-27T09:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '346',
#   'station_complex': 'Sutter Av-Rutland Rd (3)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '19.0',
#   'transfers': '0.0',
#   'latitude': '40.66472',
#   'longitude': '-73.92261',
#   'georeference': {'type': 'Point', 'coordinates': [-73.92261, 40.66472]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '890'},
#  {'transit_timestamp': '2024-05-27T09:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '364',
#   'station_complex': 'Zerega Av (6)',
#   'borough': 'Bronx',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Other',
#   'ridership': '2.0',
#   'transfers': '0.0',
#   'latitude': '40.836487',
#   'longitude': '-73.84704',
#   'georeference': {'type': 'Point', 'coordinates': [-73.84704, 40.836487]},
#   ':@computed_region_kjdx_g34t': '2032',
#   ':@computed_region_yamh_8v7k': '307',
#   ':@computed_region_wbg7_3whc': '675'},
#  {'transit_timestamp': '2024-05-27T09:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '421',
#   'station_complex': 'Gun Hill Rd (2,5)',
#   'borough': 'Bronx',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Fair Fare',
#   'ridership': '7.0',
#   'transfers': '0.0',
#   'latitude': '40.87785',
#   'longitude': '-73.86626',
#   'georeference': {'type': 'Point', 'coordinates': [-73.86626, 40.87785]},
#   ':@computed_region_kjdx_g34t': '2032',
#   ':@computed_region_yamh_8v7k': '307',
#   ':@computed_region_wbg7_3whc': '704'},
#  {'transit_timestamp': '2024-05-27T09:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '443',
#   'station_complex': 'Baychester Av (5)',
#   'borough': 'Bronx',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Fair Fare',
#   'ridership': '4.0',
#   'transfers': '0.0',
#   'latitude': '40.878662',
#   'longitude': '-73.83859',
#   'georeference': {'type': 'Point', 'coordinates': [-73.83859, 40.878662]},
#   ':@computed_region_kjdx_g34t': '2032',
#   ':@computed_region_yamh_8v7k': '307',
#   ':@computed_region_wbg7_3whc': '706'},
#  {'transit_timestamp': '2024-05-27T09:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '477',
#   'station_complex': '72 St (Q)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 30-Day',
#   'ridership': '18.0',
#   'transfers': '0.0',
#   'latitude': '40.7688',
#   'longitude': '-73.95843',
#   'georeference': {'type': 'Point', 'coordinates': [-73.95843, 40.7688]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '744'},
#  {'transit_timestamp': '2024-05-27T09:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '62',
#   'station_complex': '55 St (D)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Students',
#   'ridership': '7.0',
#   'transfers': '0.0',
#   'latitude': '40.631435',
#   'longitude': '-73.995476',
#   'georeference': {'type': 'Point', 'coordinates': [-73.995476, 40.631435]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '897'},
#  {'transit_timestamp': '2024-05-27T09:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '622',
#   'station_complex': 'Brooklyn Bridge-City Hall (4,5,6)/Chambers St (J,Z)',
#   'borough': 'Manhattan',
#   'payment_method': 'omny',
#   'fare_class_category': 'OMNY - Seniors & Disability',
#   'ridership': '2.0',
#   'transfers': '0.0',
#   'latitude': '40.71324',
#   'longitude': '-74.0034',
#   'georeference': {'type': 'Point', 'coordinates': [-74.0034, 40.71324]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '723'},
#  {'transit_timestamp': '2024-05-27T09:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '635',
#   'station_complex': 'South Ferry (1)/Whitehall St (R,W)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Fair Fare',
#   'ridership': '14.0',
#   'transfers': '4.0',
#   'latitude': '40.703087',
#   'longitude': '-74.01299',
#   'georeference': {'type': 'Point', 'coordinates': [-74.01299, 40.703087]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '720'},
#  {'transit_timestamp': '2024-05-27T10:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '107',
#   'station_complex': 'Broad St (J,Z)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Fair Fare',
#   'ridership': '1.0',
#   'transfers': '1.0',
#   'latitude': '40.706474',
#   'longitude': '-74.011055',
#   'georeference': {'type': 'Point', 'coordinates': [-74.011055, 40.706474]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '721'},
#  {'transit_timestamp': '2024-05-27T10:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '143',
#   'station_complex': 'Inwood-207 St (A)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 30-Day',
#   'ridership': '14.0',
#   'transfers': '0.0',
#   'latitude': '40.868073',
#   'longitude': '-73.9199',
#   'georeference': {'type': 'Point', 'coordinates': [-73.9199, 40.868073]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '793'},
#  {'transit_timestamp': '2024-05-27T10:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '186',
#   'station_complex': 'Van Siclen Av (C)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Students',
#   'ridership': '6.0',
#   'transfers': '0.0',
#   'latitude': '40.67271',
#   'longitude': '-73.89036',
#   'georeference': {'type': 'Point', 'coordinates': [-73.89036, 40.67271]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '885'},
#  {'transit_timestamp': '2024-05-27T10:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '20',
#   'station_complex': 'City Hall (R,W)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Full Fare',
#   'ridership': '3.0',
#   'transfers': '0.0',
#   'latitude': '40.713284',
#   'longitude': '-74.00698',
#   'georeference': {'type': 'Point', 'coordinates': [-74.00698, 40.713284]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '723'},
#  {'transit_timestamp': '2024-05-27T10:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '212',
#   'station_complex': 'Kingsbridge Rd (B,D)',
#   'borough': 'Bronx',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '17.0',
#   'transfers': '0.0',
#   'latitude': '40.866978',
#   'longitude': '-73.89351',
#   'georeference': {'type': 'Point', 'coordinates': [-73.89351, 40.866978]},
#   ':@computed_region_kjdx_g34t': '2032',
#   ':@computed_region_yamh_8v7k': '307',
#   ':@computed_region_wbg7_3whc': '654'},
#  {'transit_timestamp': '2024-05-27T10:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '292',
#   'station_complex': 'Fulton St (G)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Students',
#   'ridership': '2.0',
#   'transfers': '0.0',
#   'latitude': '40.68712',
#   'longitude': '-73.97537',
#   'georeference': {'type': 'Point', 'coordinates': [-73.97537, 40.68712]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '895'},
#  {'transit_timestamp': '2024-05-27T10:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '307',
#   'station_complex': '116 St-Columbia University (1)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '1.0',
#   'transfers': '0.0',
#   'latitude': '40.80772',
#   'longitude': '-73.96411',
#   'georeference': {'type': 'Point', 'coordinates': [-73.96411, 40.80772]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '754'},
#  {'transit_timestamp': '2024-05-27T10:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '308',
#   'station_complex': 'Cathedral Pkwy (110 St) (1)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Full Fare',
#   'ridership': '5.0',
#   'transfers': '1.0',
#   'latitude': '40.803967',
#   'longitude': '-73.96685',
#   'georeference': {'type': 'Point', 'coordinates': [-73.96685, 40.803967]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '752'},
#  {'transit_timestamp': '2024-05-27T10:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '360',
#   'station_complex': 'Pelham Bay Park (6)',
#   'borough': 'Bronx',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '8.0',
#   'transfers': '0.0',
#   'latitude': '40.852463',
#   'longitude': '-73.82812',
#   'georeference': {'type': 'Point', 'coordinates': [-73.82812, 40.852463]},
#   ':@computed_region_kjdx_g34t': '2032',
#   ':@computed_region_yamh_8v7k': '307',
#   ':@computed_region_wbg7_3whc': '674'},
#  {'transit_timestamp': '2024-05-27T10:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '374',
#   'station_complex': "E 143 St-St Mary's St (6)",
#   'borough': 'Bronx',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Full Fare',
#   'ridership': '5.0',
#   'transfers': '0.0',
#   'latitude': '40.80872',
#   'longitude': '-73.90765',
#   'georeference': {'type': 'Point', 'coordinates': [-73.90765, 40.80872]},
#   ':@computed_region_kjdx_g34t': '2032',
#   ':@computed_region_yamh_8v7k': '307',
#   ':@computed_region_wbg7_3whc': '650'},
#  {'transit_timestamp': '2024-05-27T10:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '398',
#   'station_complex': '77 St (6)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Other',
#   'ridership': '5.0',
#   'transfers': '0.0',
#   'latitude': '40.77362',
#   'longitude': '-73.95988',
#   'georeference': {'type': 'Point', 'coordinates': [-73.95988, 40.77362]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '744'},
#  {'transit_timestamp': '2024-05-27T10:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '421',
#   'station_complex': 'Gun Hill Rd (2,5)',
#   'borough': 'Bronx',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 30-Day',
#   'ridership': '11.0',
#   'transfers': '0.0',
#   'latitude': '40.87785',
#   'longitude': '-73.86626',
#   'georeference': {'type': 'Point', 'coordinates': [-73.86626, 40.87785]},
#   ':@computed_region_kjdx_g34t': '2032',
#   ':@computed_region_yamh_8v7k': '307',
#   ':@computed_region_wbg7_3whc': '704'},
#  {'transit_timestamp': '2024-05-27T10:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '436',
#   'station_complex': 'Harlem-148 St (3)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 30-Day',
#   'ridership': '5.0',
#   'transfers': '0.0',
#   'latitude': '40.82388',
#   'longitude': '-73.93647',
#   'georeference': {'type': 'Point', 'coordinates': [-73.93647, 40.82388]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '798'},
#  {'transit_timestamp': '2024-05-27T10:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '476',
#   'station_complex': '86 St (Q)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Students',
#   'ridership': '8.0',
#   'transfers': '1.0',
#   'latitude': '40.77789',
#   'longitude': '-73.95179',
#   'georeference': {'type': 'Point', 'coordinates': [-73.95179, 40.77789]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '755'},
#  {'transit_timestamp': '2024-05-27T10:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '51',
#   'station_complex': 'Kings Hwy (B,Q)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Other',
#   'ridership': '11.0',
#   'transfers': '1.0',
#   'latitude': '40.60867',
#   'longitude': '-73.95773',
#   'georeference': {'type': 'Point', 'coordinates': [-73.95773, 40.60867]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '812'},
#  {'transit_timestamp': '2024-05-27T10:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '619',
#   'station_complex': 'Broadway-Lafayette St (B,D,F,M)/Bleecker St (6)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Seniors & Disability',
#   'ridership': '6.0',
#   'transfers': '1.0',
#   'latitude': '40.725914',
#   'longitude': '-73.99466',
#   'georeference': {'type': 'Point', 'coordinates': [-73.99466, 40.725914]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '736'},
#  {'transit_timestamp': '2024-05-27T10:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '99',
#   'station_complex': 'Lorimer St (M,J)',
#   'borough': 'Brooklyn',
#   'payment_method': 'omny',
#   'fare_class_category': 'OMNY - Full Fare',
#   'ridership': '24.0',
#   'transfers': '0.0',
#   'latitude': '40.70387',
#   'longitude': '-73.94741',
#   'georeference': {'type': 'Point', 'coordinates': [-73.94741, 40.70387]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '884'},
#  {'transit_timestamp': '2024-05-27T11:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '13',
#   'station_complex': '28 St (R,W)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Fair Fare',
#   'ridership': '2.0',
#   'transfers': '0.0',
#   'latitude': '40.745495',
#   'longitude': '-73.98869',
#   'georeference': {'type': 'Point', 'coordinates': [-73.98869, 40.745495]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '717'},
#  {'transit_timestamp': '2024-05-27T11:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '209',
#   'station_complex': 'Far Rockaway-Mott Av (A)',
#   'borough': 'Queens',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Full Fare',
#   'ridership': '27.0',
#   'transfers': '3.0',
#   'latitude': '40.603996',
#   'longitude': '-73.7554',
#   'georeference': {'type': 'Point', 'coordinates': [-73.7554, 40.603996]},
#   ':@computed_region_kjdx_g34t': '2137',
#   ':@computed_region_yamh_8v7k': '196',
#   ':@computed_region_wbg7_3whc': '1027'},
#  {'transit_timestamp': '2024-05-27T11:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '243',
#   'station_complex': 'Church Av (F,G)',
#   'borough': 'Brooklyn',
#   'payment_method': 'omny',
#   'fare_class_category': 'OMNY - Full Fare',
#   'ridership': '120.0',
#   'transfers': '7.0',
#   'latitude': '40.64404',
#   'longitude': '-73.979675',
#   'georeference': {'type': 'Point', 'coordinates': [-73.979675, 40.64404]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '896'},
#  {'transit_timestamp': '2024-05-27T11:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '287',
#   'station_complex': 'Flushing Av (G)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '1.0',
#   'transfers': '0.0',
#   'latitude': '40.70038',
#   'longitude': '-73.95023',
#   'georeference': {'type': 'Point', 'coordinates': [-73.95023, 40.70038]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '884'},
#  {'transit_timestamp': '2024-05-27T11:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '321',
#   'station_complex': '18 St (1)',
#   'borough': 'Manhattan',
#   'payment_method': 'omny',
#   'fare_class_category': 'OMNY - Seniors & Disability',
#   'ridership': '2.0',
#   'transfers': '0.0',
#   'latitude': '40.74104',
#   'longitude': '-73.99787',
#   'georeference': {'type': 'Point', 'coordinates': [-73.99787, 40.74104]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '735'},
#  {'transit_timestamp': '2024-05-27T11:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '337',
#   'station_complex': 'Nevins St (2,3,4,5)',
#   'borough': 'Brooklyn',
#   'payment_method': 'omny',
#   'fare_class_category': 'OMNY - Full Fare',
#   'ridership': '66.0',
#   'transfers': '1.0',
#   'latitude': '40.688248',
#   'longitude': '-73.98049',
#   'georeference': {'type': 'Point', 'coordinates': [-73.98049, 40.688248]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '895'},
#  {'transit_timestamp': '2024-05-27T11:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '370',
#   'station_complex': 'Whitlock Av (6)',
#   'borough': 'Bronx',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Other',
#   'ridership': '2.0',
#   'transfers': '0.0',
#   'latitude': '40.826527',
#   'longitude': '-73.886284',
#   'georeference': {'type': 'Point', 'coordinates': [-73.886284, 40.826527]},
#   ':@computed_region_kjdx_g34t': '2032',
#   ':@computed_region_yamh_8v7k': '307',
#   ':@computed_region_wbg7_3whc': '655'},
#  {'transit_timestamp': '2024-05-27T11:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '403',
#   'station_complex': '33 St (6)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Fair Fare',
#   'ridership': '2.0',
#   'transfers': '0.0',
#   'latitude': '40.746082',
#   'longitude': '-73.98208',
#   'georeference': {'type': 'Point', 'coordinates': [-73.98208, 40.746082]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '739'},
#  {'transit_timestamp': '2024-05-27T11:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '620',
#   'station_complex': 'Court St (R)/Borough Hall (2,3,4,5)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '21.0',
#   'transfers': '0.0',
#   'latitude': '40.6941',
#   'longitude': '-73.99',
#   'georeference': {'type': 'Point', 'coordinates': [-73.99, 40.6941]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '880'},
#  {'transit_timestamp': '2024-05-27T11:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '99',
#   'station_complex': 'Lorimer St (M,J)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 30-Day',
#   'ridership': '21.0',
#   'transfers': '0.0',
#   'latitude': '40.70387',
#   'longitude': '-73.94741',
#   'georeference': {'type': 'Point', 'coordinates': [-73.94741, 40.70387]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '884'},
#  {'transit_timestamp': '2024-05-27T12:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '10',
#   'station_complex': '49 St (N,R,W)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Students',
#   'ridership': '13.0',
#   'transfers': '0.0',
#   'latitude': '40.7599',
#   'longitude': '-73.98414',
#   'georeference': {'type': 'Point', 'coordinates': [-73.98414, 40.7599]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '742'},
#  {'transit_timestamp': '2024-05-27T12:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '118',
#   'station_complex': '3 Av (L)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Other',
#   'ridership': '6.0',
#   'transfers': '0.0',
#   'latitude': '40.73285',
#   'longitude': '-73.98612',
#   'georeference': {'type': 'Point', 'coordinates': [-73.98612, 40.73285]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '719'},
#  {'transit_timestamp': '2024-05-27T12:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '183',
#   'station_complex': 'Rockaway Av (C)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Full Fare',
#   'ridership': '15.0',
#   'transfers': '0.0',
#   'latitude': '40.67834',
#   'longitude': '-73.91195',
#   'georeference': {'type': 'Point', 'coordinates': [-73.91195, 40.67834]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '816'},
#  {'transit_timestamp': '2024-05-27T12:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '205',
#   'station_complex': 'Beach 60 St (A)',
#   'borough': 'Queens',
#   'payment_method': 'omny',
#   'fare_class_category': 'OMNY - Full Fare',
#   'ridership': '15.0',
#   'transfers': '0.0',
#   'latitude': '40.592373',
#   'longitude': '-73.78852',
#   'georeference': {'type': 'Point', 'coordinates': [-73.78852, 40.592373]},
#   ':@computed_region_kjdx_g34t': '2137',
#   ':@computed_region_yamh_8v7k': '196',
#   ':@computed_region_wbg7_3whc': '1028'},
#  {'transit_timestamp': '2024-05-27T12:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '241',
#   'station_complex': '15 St-Prospect Park (F,G)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Other',
#   'ridership': '4.0',
#   'transfers': '1.0',
#   'latitude': '40.660366',
#   'longitude': '-73.97949',
#   'georeference': {'type': 'Point', 'coordinates': [-73.97949, 40.660366]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '893'},
#  {'transit_timestamp': '2024-05-27T12:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '3',
#   'station_complex': '30 Av (N,W)',
#   'borough': 'Queens',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Full Fare',
#   'ridership': '32.0',
#   'transfers': '0.0',
#   'latitude': '40.76678',
#   'longitude': '-73.92148',
#   'georeference': {'type': 'Point', 'coordinates': [-73.92148, 40.76678]},
#   ':@computed_region_kjdx_g34t': '2137',
#   ':@computed_region_yamh_8v7k': '196',
#   ':@computed_region_wbg7_3whc': '874'},
#  {'transit_timestamp': '2024-05-27T12:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '347',
#   'station_complex': 'Saratoga Av (3)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Other',
#   'ridership': '5.0',
#   'transfers': '0.0',
#   'latitude': '40.661453',
#   'longitude': '-73.91633',
#   'georeference': {'type': 'Point', 'coordinates': [-73.91633, 40.661453]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '890'},
#  {'transit_timestamp': '2024-05-27T12:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '384',
#   'station_complex': 'Burnside Av (4)',
#   'borough': 'Bronx',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '15.0',
#   'transfers': '0.0',
#   'latitude': '40.853455',
#   'longitude': '-73.907684',
#   'georeference': {'type': 'Point', 'coordinates': [-73.907684, 40.853455]},
#   ':@computed_region_kjdx_g34t': '2032',
#   ':@computed_region_yamh_8v7k': '307',
#   ':@computed_region_wbg7_3whc': '649'},
#  {'transit_timestamp': '2024-05-27T12:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '416',
#   'station_complex': 'Wakefield-241 St (2)',
#   'borough': 'Bronx',
#   'payment_method': 'omny',
#   'fare_class_category': 'OMNY - Full Fare',
#   'ridership': '20.0',
#   'transfers': '0.0',
#   'latitude': '40.903126',
#   'longitude': '-73.85062',
#   'georeference': {'type': 'Point', 'coordinates': [-73.85062, 40.903126]},
#   ':@computed_region_kjdx_g34t': '2185',
#   ':@computed_region_yamh_8v7k': '307',
#   ':@computed_region_wbg7_3whc': '707'},
#  {'transit_timestamp': '2024-05-27T12:00:00.000',
#   'transit_mode': 'subway',
# ...
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 30-Day',
#   'ridership': '26.0',
#   'transfers': '0.0',
#   'latitude': '40.754223',
#   'longitude': '-73.981964',
#   'georeference': {'type': 'Point', 'coordinates': [-73.981964, 40.754223]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '578'},
#  {'transit_timestamp': '2024-05-27T01:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '114',
#   'station_complex': 'Central Av (M)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Full Fare',
#   'ridership': '1.0',
#   'transfers': '0.0',
#   'latitude': '40.697857',
#   'longitude': '-73.9274',
#   'georeference': {'type': 'Point', 'coordinates': [-73.9274, 40.697857]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '900'},
#  {'transit_timestamp': '2024-05-27T01:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '124',
#   'station_complex': 'Montrose Av (L)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 30-Day',
#   'ridership': '4.0',
#   'transfers': '0.0',
#   'latitude': '40.70774',
#   'longitude': '-73.93985',
#   'georeference': {'type': 'Point', 'coordinates': [-73.93985, 40.70774]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '884'},
#  {'transit_timestamp': '2024-05-27T01:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '125',
#   'station_complex': 'Morgan Av (L)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Seniors & Disability',
#   'ridership': '2.0',
#   'transfers': '0.0',
#   'latitude': '40.706154',
#   'longitude': '-73.93314',
#   'georeference': {'type': 'Point', 'coordinates': [-73.93314, 40.706154]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '884'},
#  {'transit_timestamp': '2024-05-27T01:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '183',
#   'station_complex': 'Rockaway Av (C)',
#   'borough': 'Brooklyn',
#   'payment_method': 'omny',
#   'fare_class_category': 'OMNY - Full Fare',
#   'ridership': '4.0',
#   'transfers': '0.0',
#   'latitude': '40.67834',
#   'longitude': '-73.91195',
#   'georeference': {'type': 'Point', 'coordinates': [-73.91195, 40.67834]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '816'},
#  {'transit_timestamp': '2024-05-27T01:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '264',
#   'station_complex': 'Woodhaven Blvd (M,R)',
#   'borough': 'Queens',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '2.0',
#   'transfers': '0.0',
#   'latitude': '40.733105',
#   'longitude': '-73.86923',
#   'georeference': {'type': 'Point', 'coordinates': [-73.86923, 40.733105]},
#   ':@computed_region_kjdx_g34t': '2137',
#   ':@computed_region_yamh_8v7k': '196',
#   ':@computed_region_wbg7_3whc': '843'},
#  {'transit_timestamp': '2024-05-27T01:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '299',
#   'station_complex': 'Dyckman St (1)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Full Fare',
#   'ridership': '4.0',
#   'transfers': '0.0',
#   'latitude': '40.86053',
#   'longitude': '-73.92554',
#   'georeference': {'type': 'Point', 'coordinates': [-73.92554, 40.86053]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '799'},
#  {'transit_timestamp': '2024-05-27T01:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '33',
#   'station_complex': '45 St (R)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '3.0',
#   'transfers': '0.0',
#   'latitude': '40.648937',
#   'longitude': '-74.01001',
#   'georeference': {'type': 'Point', 'coordinates': [-74.01001, 40.648937]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '899'},
#  {'transit_timestamp': '2024-05-27T01:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '34',
#   'station_complex': '53 St (R)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '2.0',
#   'transfers': '0.0',
#   'latitude': '40.64507',
#   'longitude': '-74.01403',
#   'georeference': {'type': 'Point', 'coordinates': [-74.01403, 40.64507]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '899'},
#  {'transit_timestamp': '2024-05-27T01:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '378',
#   'station_complex': 'Woodlawn (4)',
#   'borough': 'Bronx',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Full Fare',
#   'ridership': '1.0',
#   'transfers': '0.0',
#   'latitude': '40.886036',
#   'longitude': '-73.87875',
#   'georeference': {'type': 'Point', 'coordinates': [-73.87875, 40.886036]},
#   ':@computed_region_kjdx_g34t': '2032',
#   ':@computed_region_yamh_8v7k': '307',
#   ':@computed_region_wbg7_3whc': '704'},
#  {'transit_timestamp': '2024-05-27T01:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '393',
#   'station_complex': '116 St (6)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '1.0',
#   'transfers': '0.0',
#   'latitude': '40.79863',
#   'longitude': '-73.94162',
#   'georeference': {'type': 'Point', 'coordinates': [-73.94162, 40.79863]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '756'},
#  {'transit_timestamp': '2024-05-27T01:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '405',
#   'station_complex': '23 St (6)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Other',
#   'ridership': '1.0',
#   'transfers': '0.0',
#   'latitude': '40.739864',
#   'longitude': '-73.9866',
#   'georeference': {'type': 'Point', 'coordinates': [-73.9866, 40.739864]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '734'},
#  {'transit_timestamp': '2024-05-27T01:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '421',
#   'station_complex': 'Gun Hill Rd (2,5)',
#   'borough': 'Bronx',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '1.0',
#   'transfers': '0.0',
#   'latitude': '40.87785',
#   'longitude': '-73.86626',
#   'georeference': {'type': 'Point', 'coordinates': [-73.86626, 40.87785]},
#   ':@computed_region_kjdx_g34t': '2032',
#   ':@computed_region_yamh_8v7k': '307',
#   ':@computed_region_wbg7_3whc': '704'},
#  {'transit_timestamp': '2024-05-27T01:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '439',
#   'station_complex': '125 St (2,3)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Fair Fare',
#   'ridership': '3.0',
#   'transfers': '0.0',
#   'latitude': '40.807755',
#   'longitude': '-73.945496',
#   'georeference': {'type': 'Point', 'coordinates': [-73.945496, 40.807755]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '754'},
#  {'transit_timestamp': '2024-05-27T01:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '455',
#   'station_complex': '69 St (7)',
#   'borough': 'Queens',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Full Fare',
#   'ridership': '1.0',
#   'transfers': '0.0',
#   'latitude': '40.746326',
#   'longitude': '-73.8964',
#   'georeference': {'type': 'Point', 'coordinates': [-73.8964, 40.746326]},
#   ':@computed_region_kjdx_g34t': '2137',
#   ':@computed_region_yamh_8v7k': '196',
#   ':@computed_region_wbg7_3whc': '846'},
#  {'transit_timestamp': '2024-05-27T01:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '47',
#   'station_complex': 'Newkirk Plaza (B,Q)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Full Fare',
#   'ridership': '1.0',
#   'transfers': '0.0',
#   'latitude': '40.635082',
#   'longitude': '-73.96279',
#   'georeference': {'type': 'Point', 'coordinates': [-73.96279, 40.635082]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '810'},
#  {'transit_timestamp': '2024-05-27T01:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '78',
#   'station_complex': 'Avenue U (N)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 30-Day',
#   'ridership': '1.0',
#   'transfers': '0.0',
#   'latitude': '40.597473',
#   'longitude': '-73.97913',
#   'georeference': {'type': 'Point', 'coordinates': [-73.97913, 40.597473]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '902'},
#  {'transit_timestamp': '2024-05-27T02:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '152',
#   'station_complex': '135 St (C,B)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Fair Fare',
#   'ridership': '2.0',
#   'transfers': '0.0',
#   'latitude': '40.817894',
#   'longitude': '-73.94765',
#   'georeference': {'type': 'Point', 'coordinates': [-73.94765, 40.817894]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '757'},
#  {'transit_timestamp': '2024-05-27T02:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '196',
#   'station_complex': 'Aqueduct Racetrack (A)',
#   'borough': 'Queens',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Other',
#   'ridership': '1.0',
#   'transfers': '0.0',
#   'latitude': '40.672096',
#   'longitude': '-73.83592',
#   'georeference': {'type': 'Point', 'coordinates': [-73.83592, 40.672096]},
#   ':@computed_region_kjdx_g34t': '2137',
#   ':@computed_region_yamh_8v7k': '196',
#   ':@computed_region_wbg7_3whc': '1164'},
#  {'transit_timestamp': '2024-05-27T02:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '228',
#   'station_complex': '23 St (F,M)',
#   'borough': 'Manhattan',
#   'payment_method': 'omny',
#   'fare_class_category': 'OMNY - Full Fare',
#   'ridership': '15.0',
#   'transfers': '0.0',
#   'latitude': '40.742878',
#   'longitude': '-73.99282',
#   'georeference': {'type': 'Point', 'coordinates': [-73.99282, 40.742878]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '734'},
#  {'transit_timestamp': '2024-05-27T02:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '240',
#   'station_complex': '7 Av (F,G)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '2.0',
#   'transfers': '0.0',
#   'latitude': '40.66627',
#   'longitude': '-73.98031',
#   'georeference': {'type': 'Point', 'coordinates': [-73.98031, 40.66627]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '893'},
#  {'transit_timestamp': '2024-05-27T02:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '9',
#   'station_complex': '57 St-7 Av (N,Q,R,W)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Fair Fare',
#   'ridership': '1.0',
#   'transfers': '0.0',
#   'latitude': '40.764664',
#   'longitude': '-73.98066',
#   'georeference': {'type': 'Point', 'coordinates': [-73.98066, 40.764664]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '742'},
#  {'transit_timestamp': '2024-05-27T03:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '188',
#   'station_complex': 'Euclid Av (A,C)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Seniors & Disability',
#   'ridership': '1.0',
#   'transfers': '0.0',
#   'latitude': '40.675377',
#   'longitude': '-73.87211',
#   'georeference': {'type': 'Point', 'coordinates': [-73.87211, 40.675377]},
#   ':@computed_region_kjdx_g34t': '2137',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '886'},
#  {'transit_timestamp': '2024-05-27T03:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '209',
#   'station_complex': 'Far Rockaway-Mott Av (A)',
#   'borough': 'Queens',
#   'payment_method': 'omny',
#   'fare_class_category': 'OMNY - Full Fare',
#   'ridership': '5.0',
#   'transfers': '0.0',
#   'latitude': '40.603996',
#   'longitude': '-73.7554',
#   'georeference': {'type': 'Point', 'coordinates': [-73.7554, 40.603996]},
#   ':@computed_region_kjdx_g34t': '2137',
#   ':@computed_region_yamh_8v7k': '196',
#   ':@computed_region_wbg7_3whc': '1027'},
#  {'transit_timestamp': '2024-05-27T03:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '211',
#   'station_complex': 'Bedford Park Blvd (B,D)',
#   'borough': 'Bronx',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '2.0',
#   'transfers': '0.0',
#   'latitude': '40.873245',
#   'longitude': '-73.88714',
#   'georeference': {'type': 'Point', 'coordinates': [-73.88714, 40.873245]},
#   ':@computed_region_kjdx_g34t': '2032',
#   ':@computed_region_yamh_8v7k': '307',
#   ':@computed_region_wbg7_3whc': '654'},
#  {'transit_timestamp': '2024-05-27T03:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '627',
#   'station_complex': 'Franklin Av (C,S)',
#   'borough': 'Brooklyn',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Full Fare',
#   'ridership': '1.0',
#   'transfers': '0.0',
#   'latitude': '40.68138',
#   'longitude': '-73.95685',
#   'georeference': {'type': 'Point', 'coordinates': [-73.95685, 40.68138]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '821'},
#  {'transit_timestamp': '2024-05-27T04:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '108',
#   'station_complex': 'Middle Village-Metropolitan Av (M)',
#   'borough': 'Queens',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Full Fare',
#   'ridership': '1.0',
#   'transfers': '0.0',
#   'latitude': '40.711395',
#   'longitude': '-73.8896',
#   'georeference': {'type': 'Point', 'coordinates': [-73.8896, 40.711395]},
#   ':@computed_region_kjdx_g34t': '2137',
#   ':@computed_region_yamh_8v7k': '196',
#   ':@computed_region_wbg7_3whc': '848'},
#  {'transit_timestamp': '2024-05-27T04:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '113',
#   'station_complex': 'Knickerbocker Av (M)',
#   'borough': 'Brooklyn',
#   'payment_method': 'omny',
#   'fare_class_category': 'OMNY - Full Fare',
#   'ridership': '3.0',
#   'transfers': '0.0',
#   'latitude': '40.698666',
#   'longitude': '-73.91971',
#   'georeference': {'type': 'Point', 'coordinates': [-73.91971, 40.698666]},
#   ':@computed_region_kjdx_g34t': '2090',
#   ':@computed_region_yamh_8v7k': '894',
#   ':@computed_region_wbg7_3whc': '820'},
#  {'transit_timestamp': '2024-05-27T04:00:00.000',
#   'transit_mode': 'subway',
#   'station_complex_id': '164',
#   'station_complex': '34 St-Penn Station (A,C,E)',
#   'borough': 'Manhattan',
#   'payment_method': 'metrocard',
#   'fare_class_category': 'Metrocard - Unlimited 7-Day',
#   'ridership': '3.0',
#   'transfers': '0.0',
#   'latitude': '40.75229',
#   'longitude': '-73.99339',
#   'georeference': {'type': 'Point', 'coordinates': [-73.99339, 40.75229]},
#   ':@computed_region_kjdx_g34t': '2095',
#   ':@computed_region_yamh_8v7k': '749',
#   ':@computed_region_wbg7_3whc': '717'},
#  ...]

# %%
# Convert results to DataFrame
df = pd.DataFrame.from_records(results)
# Convert 'transit_timestamp' to datetime
df['transit_timestamp'] = pd.to_datetime(df['transit_timestamp'])
# Convert 'ridership' to numeric
df['ridership'] = pd.to_numeric(df['ridership'], errors='coerce')
df
# Out:
#          transit_timestamp transit_mode station_complex_id  \
# 0      2024-09-17 05:00:00       subway                392
# 1      2024-05-27 06:00:00       subway                419
# 2      2024-05-27 06:00:00       subway                427
# 3      2024-05-27 06:00:00       subway                 47
# 4      2024-05-27 06:00:00       subway                471
# ...                    ...          ...                ...
# 499995 2024-08-10 16:00:00       subway                298
# 499996 2024-08-10 16:00:00       subway                347
# 499997 2024-08-10 16:00:00       subway                369
# 499998 2024-08-10 16:00:00       subway                384
# 499999 2024-08-10 16:00:00       subway                404
#
#                          station_complex    borough payment_method  \
# 0                         125 St (4,5,6)  Manhattan      metrocard
# 1                           225 St (2,5)      Bronx      metrocard
# 2       West Farms Sq-E Tremont Av (2,5)      Bronx      metrocard
# 3                    Newkirk Plaza (B,Q)   Brooklyn           omny
# 4                 34 St-Hudson Yards (7)  Manhattan      metrocard
# ...                                  ...        ...            ...
# 499995                        207 St (1)  Manhattan      metrocard
# 499996                   Saratoga Av (3)   Brooklyn      metrocard
# 499997                      Elder Av (6)      Bronx      metrocard
# 499998                   Burnside Av (4)      Bronx      metrocard
# 499999                         28 St (6)  Manhattan           omny
#
#                      fare_class_category  ridership transfers   latitude  \
# 0                  Metrocard - Fair Fare       13.0       0.0   40.80414
# 1                      Metrocard - Other        1.0       0.0  40.888023
# 2                      Metrocard - Other        6.0       1.0  40.840294
# 3                       OMNY - Full Fare       65.0       3.0  40.635082
# 4                  Metrocard - Fair Fare        3.0       0.0  40.755882
# ...                                  ...        ...       ...        ...
# 499995             Metrocard - Fair Fare       16.0       2.0   40.86462
# 499996             Metrocard - Fair Fare        8.0       0.0  40.661453
# 499997  Metrocard - Seniors & Disability        7.0       0.0  40.828583
# 499998             Metrocard - Fair Fare       21.0       0.0  40.853455
# 499999       OMNY - Seniors & Disability        1.0       0.0   40.74307
#
#          longitude                                       georeference  \
# 0        -73.93759  {'type': 'Point', 'coordinates': [-73.93759, 4...
# 1       -73.860344  {'type': 'Point', 'coordinates': [-73.860344, ...
# 2        -73.88005  {'type': 'Point', 'coordinates': [-73.88005, 4...
# 3        -73.96279  {'type': 'Point', 'coordinates': [-73.96279, 4...
# 4        -74.00191  {'type': 'Point', 'coordinates': [-74.00191, 4...
# ...            ...                                                ...
# 499995   -73.91882  {'type': 'Point', 'coordinates': [-73.91882, 4...
# 499996   -73.91633  {'type': 'Point', 'coordinates': [-73.91633, 4...
# 499997   -73.87916  {'type': 'Point', 'coordinates': [-73.87916, 4...
# 499998  -73.907684  {'type': 'Point', 'coordinates': [-73.907684, ...
# 499999   -73.98426  {'type': 'Point', 'coordinates': [-73.98426, 4...
#
#        :@computed_region_kjdx_g34t :@computed_region_yamh_8v7k  \
# 0                             2095                         749
# 1                             2032                         307
# 2                             2032                         307
# 3                             2090                         894
# 4                             2095                         749
# ...                            ...                         ...
# 499995                        2095                         749
# 499996                        2090                         894
# 499997                        2032                         307
# 499998                        2032                         307
# 499999                        2095                         749
#
#        :@computed_region_wbg7_3whc
# 0                              794
# 1                              679
# 2                              673
# 3                              810
# 4                              717
# ...                            ...
# 499995                         793
# 499996                         890
# 499997                         709
# 499998                         649
# 499999                         739
#
# [500000 rows x 15 columns]

# %%
# Descending timestamps
ordered_df = df.sort_values(by='transit_timestamp', ascending=False)
ordered_df
# Out:
#          transit_timestamp transit_mode station_complex_id  station_complex  \
# 55423  2024-09-17 23:00:00       subway                  4   Broadway (N,W)
# 108268 2024-09-17 23:00:00       subway                373     E 149 St (6)
# 181484 2024-09-17 23:00:00       subway                119         1 Av (L)
# 95000  2024-09-17 22:00:00       subway                236  Bergen St (F,G)
# 135288 2024-09-17 22:00:00       subway                 66        18 Av (D)
# ...                    ...          ...                ...              ...
# 121650 2024-05-01 01:00:00       subway                393       116 St (6)
# 157931 2024-05-01 01:00:00       subway                347  Saratoga Av (3)
# 175513 2024-05-01 00:00:00       subway                 51  Kings Hwy (B,Q)
# 120881 2024-05-01 00:00:00       subway                103     Bowery (J,Z)
# 120990 2024-05-01 00:00:00       subway                224        57 St (F)
#
#           borough payment_method           fare_class_category  ridership  \
# 55423      Queens      metrocard  Metrocard - Unlimited 30-Day        2.0
# 108268      Bronx      metrocard   Metrocard - Unlimited 7-Day        5.0
# 181484  Manhattan      metrocard         Metrocard - Fair Fare       17.0
# 95000    Brooklyn           omny   OMNY - Seniors & Disability        1.0
# 135288   Brooklyn      metrocard         Metrocard - Fair Fare        1.0
# ...           ...            ...                           ...        ...
# 121650  Manhattan           omny              OMNY - Full Fare        4.0
# 157931   Brooklyn      metrocard             Metrocard - Other        1.0
# 175513   Brooklyn      metrocard             Metrocard - Other        3.0
# 120881  Manhattan           omny              OMNY - Full Fare       36.0
# 120990  Manhattan      metrocard             Metrocard - Other        3.0
#
#        transfers   latitude  longitude  \
# 55423        0.0   40.76182  -73.92551
# 108268       0.0   40.81212   -73.9041
# 181484       0.0  40.730953  -73.98163
# 95000        0.0  40.686146  -73.99086
# 135288       0.0  40.607952  -74.00174
# ...          ...        ...        ...
# 121650       0.0   40.79863  -73.94162
# 157931       0.0  40.661453  -73.91633
# 175513       0.0   40.60867  -73.95773
# 120881       1.0   40.72028  -73.99391
# 120990       0.0  40.763973  -73.97745
#
#                                              georeference  \
# 55423   {'type': 'Point', 'coordinates': [-73.92551, 4...
# 108268  {'type': 'Point', 'coordinates': [-73.9041, 40...
# 181484  {'type': 'Point', 'coordinates': [-73.98163, 4...
# 95000   {'type': 'Point', 'coordinates': [-73.99086, 4...
# 135288  {'type': 'Point', 'coordinates': [-74.00174, 4...
# ...                                                   ...
# 121650  {'type': 'Point', 'coordinates': [-73.94162, 4...
# 157931  {'type': 'Point', 'coordinates': [-73.91633, 4...
# 175513  {'type': 'Point', 'coordinates': [-73.95773, 4...
# 120881  {'type': 'Point', 'coordinates': [-73.99391, 4...
# 120990  {'type': 'Point', 'coordinates': [-73.97745, 4...
#
#        :@computed_region_kjdx_g34t :@computed_region_yamh_8v7k  \
# 55423                         2137                         196
# 108268                        2032                         307
# 181484                        2095                         749
# 95000                         2090                         894
# 135288                        2090                         894
# ...                            ...                         ...
# 121650                        2095                         749
# 157931                        2090                         894
# 175513                        2090                         894
# 120881                        2095                         749
# 120990                        2095                         749
#
#        :@computed_region_wbg7_3whc
# 55423                          878
# 108268                         651
# 181484                         724
# 95000                          880
# 135288                         892
# ...                            ...
# 121650                         756
# 157931                         890
# 175513                         812
# 120881                         718
# 120990                         742
#
# [500000 rows x 15 columns]

# %%
def predict_ridership(station_complex_id, day_of_week, hour):
    # Format the input features as a DataFrame
    input_features = pd.DataFrame({
        'station_complex_id': [station_complex_id],
        'day_of_week': [day_of_week],
        'hour': [hour]
    })
    # Predict ridership
    predicted_ridership = model.predict(input_features)
    return predicted_ridership[0]

# Example usage
station_id_example = 164  # Replace with an actual station_complex_id
day_of_week_example = 6  # Friday
hour_example = 15  # 8 AM
prediction = predict_ridership(station_id_example, day_of_week_example, hour_example)
print(f"Predicted ridership for station ID {station_id_example} on day {day_of_week_example} at hour {hour_example}: {prediction}")
# Out:
# Predicted ridership for station ID 164 on day 6 at hour 15: 1480.4707055659012
